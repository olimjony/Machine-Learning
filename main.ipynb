# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %config InlineBackend.figure_fornmat = 'svg'

from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
import  pandas as pd
data = pd.read_csv('World_Happiness_Report.csv')

# %%
data.head(156)
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#translations = {
#    'Overall rank': 'Общий рейтинг',
#    'Country or region': 'Страна или регион',
#    'Score': 'Оценка',
#   'GDP per capita': 'ВВП на душу населения',
#    'Social support': 'Социальная поддержка',
#    'Healthy life expectancy': 'Ожидаемая продолжительность здоровой жизни',
#    'Freedom to make life choices': 'Свобода выбора жизненного пути',
#    'Generosity': 'Щедрость',
#    'Perceptions of corruption': 'Восприятие коррупции'
#}

# Переименование столбцов с помощью словаря переводов
#data.rename(columns=translations, inplace=True)

# Вывод данных
#data

# %%
data.shape
# Out:
# (156, 9)

# %%
data.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
##data['Country or region'] = data['Country or region'].astype('string')
##data['Overall rank'] = data['Overall rank'].astype('float64')

data['Country or region'] = data['Country or region'].astype('object')
data['Overall rank'] = data['Overall rank'].astype('int64')

data.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
data = data.rename(columns={'Country or region': 'Country'})

sorted_data = data.sort_values(by='Overall rank', ascending=True)

sorted_data
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
data.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
numeric_columns = data.drop(columns='Overall rank').select_dtypes(include=['float64', 'int64']).columns

for i in range(len(numeric_columns)):
    for j in range(i+1, len(numeric_columns)):
        plt.figure(figsize=(8, 6))
        sns.scatterplot(data=data, x=numeric_columns[i], y=numeric_columns[j])
        plt.title(f'Раcпределение между {numeric_columns[i]} и {numeric_columns[j]}')
        plt.xlabel(numeric_columns[i])
        plt.ylabel(numeric_columns[j])
        plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=data[['GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']], orient='h')
plt.xticks(rotation=90)
plt.show()

# %%
data_without_country = data.drop(columns=['Country','Overall rank'])
correlation_matrix = data_without_country.corr()
correlation_matrix
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.793883        0.777058
# GDP per capita                0.793883        1.000000        0.754906
# Social support                0.777058        0.754906        1.000000
# Healthy life expectancy       0.779883        0.835462        0.719009
# Freedom to make life choices  0.566742        0.379079        0.447333
# Generosity                    0.075824       -0.079662       -0.048126
# Perceptions of corruption     0.385613        0.298920        0.181899
#
#                               Healthy life expectancy  \
# Score                                        0.779883
# GDP per capita                               0.835462
# Social support                               0.719009
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.390395
# Generosity                                  -0.029511
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
